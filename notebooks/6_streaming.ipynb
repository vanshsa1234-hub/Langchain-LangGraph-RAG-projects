# %%
from dotenv import load_dotenv
load_dotenv()

# %%
from langchain_groq import ChatGroq
llm=ChatGroq(model="openai/gpt-oss-120b")

# %%
question="What is streaming in the context of LLMs?"
response=llm.stream(question)
for chunk in response:
    print(chunk.content,end="")
# Out:
# ## What is “Gen‑AI”?
#
# **Gen‑AI** (short for **generative artificial intelligence**) refers to a class of machine‑learning systems that can **create new content**—text, images, audio, video, code, or even 3‑D models—rather than just analyzing or classifying existing data.
# In other words, instead of answering “What is this picture?” a generative model can answer “Here’s a picture that looks like this” or “Write a story about this prompt.”
#
# ---
#
# ## 1. How Generative AI Works (High‑Level Overview)
#
# | Step | What Happens | Example |
# |------|--------------|---------|
# | **1️⃣ Data collection** | Gather massive datasets of the target modality (e.g., billions of words, millions of images). | A web‑scraped corpus of English text, a collection of photos from Flickr. |
# | **2️⃣ Model architecture** | Choose a neural‑network design that can learn the statistical patterns in the data. Common families: | • **Transformer** (e.g., GPT, BERT, T5) – excels at sequences like text.<br>• **Diffusion models** (e.g., Stable Diffusion, DALL‑E 2) – excel at images.<br>• **GANs** (Generative Adversarial Networks) – also used for images, video, audio.<br>• **Variational Autoencoders (VAEs)** – useful for latent‑space manipulation. |
# | **3️⃣ Training** | Use self‑supervised or unsupervised objectives (e.g., next‑token prediction, denoising) to adjust billions of parameters so the model captures the data distribution. | GPT‑4 was trained to predict the next word in a sentence given the preceding context. |
# | **4️⃣ Inference (generation)** | Feed a **prompt** (a short piece of text, a sketch, a melody, etc.) and let the model sample from its learned distribution to produce new output. | Prompt: “A futuristic city at sunset” → Image generated by Stable Diffusion. |
# | **5️⃣ Post‑processing (optional)** | Apply filters, safety checks, or refinement models to improve quality or enforce constraints. | Use a “classifier‑free guidance” step to make the image more faithful to the prompt. |
#
# ---
#
# ## 2. Core Model Families
#
# | Family | Typical Output | Key Idea | Notable Examples |
# |--------|----------------|----------|-------------------|
# | **Transformer‑based language models** | Text (articles, code, chat) | Autoregressive next‑token prediction; attention mechanism captures long‑range dependencies. | GPT‑4, LLaMA, Claude, PaLM, Gemini |
# | **Diffusion models** | Images, videos, audio | Start from random noise and iteratively denoise it guided by a learned model. | Stable Diffusion, DALL·E 2, Imagen, Midjourney |
# | **GANs (Generative Adversarial Networks)** | Images, video, audio | Two networks (generator vs. discriminator) compete; the generator learns to produce realistic samples. | StyleGAN, BigGAN |
# | **Variational Autoencoders (VAEs)** | Images, 3‑D shapes, music | Encode data into a latent space, then decode; encourages smooth, interpolable latent representations. | VQ‑VAE‑2, MusicVAE |
# | **Multimodal models** | Text + image + audio together | Jointly learn representations across modalities, enabling cross‑modal generation (e.g., text‑to‑image). | CLIP + diffusion pipelines, Flamingo, Gemini (multimodal), LLaVA |
#
# ---
#
# ## 3. What Generative AI Can Do (Applications)
#
# | Domain | Use‑Cases | Example Tools |
# |--------|----------|---------------|
# | **Content creation** | Blog posts, marketing copy, scripts, code snippets | ChatGPT, Copilot, Claude |
# | **Design & art** | Concept art, product mock‑ups, fashion sketches | Midjourney, Stable Diffusion, DALL·E |
# | **Audio & music** | Composing melodies, voice synthesis, sound effects | Jukebox, Riffusion, Bark |
# | **Video & animation** | Short clips, storyboards, deep‑fake style effects | Sora (OpenAI), Runway Gen‑2 |
# | **Software engineering** | Auto‑complete code, generate tests, refactor, documentation | GitHub Copilot, Tabnine |
# | **Education & tutoring** | Explain concepts, generate practice problems, language practice | Khan Academy’s AI tutor, Duolingo AI |
# | **Healthcare** | Drafting radiology reports, molecule generation for drug discovery | MedPaLM, AlphaFold‑2 (structure generation) |
# | **Business intelligence** | Summarize reports, generate presentations, data‑to‑text narratives | Jasper, Synthesia |
# | **Gaming** | Procedural level design, NPC dialogue, quest generation | AI Dungeon, Inworld AI |
#
# ---
#
# ## 4. Why Generative AI Is Different From Classic AI
#
# | Classic AI (e.g., classification) | Generative AI |
# |-----------------------------------|---------------|
# | **Goal:** Assign a label or predict a property (e.g., “Is this email spam?”). | **Goal:** Produce *new* data that looks like it came from the training distribution. |
# | **Training signal:** Supervised loss (cross‑entropy) on known targets. | **Training signal:** Self‑supervised loss (next token, denoise) where the target is derived from the input itself. |
# | **Output:** Discrete, deterministic (often a single class). | **Output:** High‑dimensional, stochastic (many possible valid outputs). |
# | **Evaluation:** Accuracy, precision, recall. | **Evaluation:** Perceptual quality, fidelity, diversity, alignment with user intent. |
#
# ---
#
# ## 5. Safety, Ethics, and Limitations
#
# | Concern | What It Looks Like | Mitigation Strategies |
# |---------|-------------------|-----------------------|
# | **Hallucinations** | Model fabricates facts, code bugs, or nonsensical images. | Retrieval‑augmented generation, fact‑checking pipelines, human‑in‑the‑loop review. |
# | **Bias & unfairness** | Outputs reflect societal biases present in the training data. | Curated datasets, bias‑aware fine‑tuning, post‑generation filters, transparent reporting. |
# | **Misinformation & deepfakes** | Realistic synthetic media can be weaponized. | Watermarking, provenance tracking, detection tools, policy & legal frameworks. |
# | **Intellectual‑property issues** | Generated content may inadvertently copy copyrighted material. | Training on licensed data, usage policies, attribution mechanisms. |
# | **Resource consumption** | Training large models can cost millions of dollars and emit large CO₂. | Efficient architectures (e.g., sparsity, quantization), model distillation, shared compute clusters. |
# | **Prompt injection / jailbreaks** | Users craft prompts to force the model to violate its safety guardrails. | Robust alignment, multi‑step verification, sandboxed execution. |
#
# ---
#
# ## 6. The Current Landscape (2024‑2025 Snapshot)
#
# | Company / Lab | Flagship Model(s) | Notable Strength |
# |---------------|-------------------|------------------|
# | **OpenAI** | GPT‑4o (multimodal), DALL·E 3, Sora (video) | Strong language + image integration, high reliability. |
# | **Google DeepMind / Google AI** | Gemini (multimodal), PaLM‑2, Imagen 3 | Tight coupling of language and vision, advanced reasoning. |
# | **Microsoft + Anthropic** | Claude 3, Azure OpenAI Service | Enterprise‑grade compliance, customizable “assistant” personas. |
# | **Meta** | LLaMA‑3, Stable Diffusion 3.0 | Open‑source‑first, large community ecosystem. |
# | **Stability AI** | Stable Diffusion XL, DreamStudio | Fast, customizable diffusion pipelines, strong community plugins. |
# | **Adobe** | Firefly | Integrated creative‑suite tools with IP‑safe training data. |
# | **NVIDIA** | Canvas, AudioCraft | GPU‑optimized diffusion models for graphics and audio. |
#
# *Trend:* **Multimodal convergence**—most new releases can handle text, images, and sometimes audio/video in a single model, making “one‑stop‑shop” assistants increasingly feasible.
#
# ---
#
# ## 7. How to Get Started with Generative AI
#
# 1. **Pick a Modality** – Decide whether you need text, images, audio, or a combination.
# 2. **Choose a Platform** –
#    - **Hosted APIs** (OpenAI, Anthropic, Google Vertex AI, Stability AI) for quick prototyping.
#    - **Open‑source libraries** (🤗 Transformers, Diffusers, LangChain) if you need full control or offline use.
# 3. **Define Prompting Strategy** – Good prompts often follow a *few‑shot* or *instruction* pattern: give the model a short example of the desired output.
# 4. **Iterate & Refine** – Use temperature, top‑p, or guidance scales to trade off creativity vs. fidelity.
# 5. **Add Safety Layers** – Filter outputs with classifiers (e.g., toxicity, copyrighted‑content detectors) and implement human review for high‑risk domains.
# 6. **Deploy** – Wrap the model in an API, UI, or integration (e.g., a chatbot, a design plugin).
#
# **Quick Example (Python + Hugging Face Diffusers):**
#
# ```python
# from diffusers import StableDiffusionPipeline
# import torch
#
# pipe = StableDiffusionPipeline.from_pretrained(
#     "stabilityai/stable-diffusion-xl-base-1.0",
#     torch_dtype=torch.float16,
#     variant="fp16"
# ).to("cuda")
#
# prompt = "A futuristic city skyline at sunset, ultra‑realistic, cinematic lighting"
# image = pipe(prompt, guidance_scale=7.5).images[0]
#
# image.save("city.png")
# ```
#
# That snippet downloads a state‑of‑the‑art diffusion model and generates a high‑quality image from a one‑sentence prompt.
#
# ---
#
# ## 8. Future Directions
#
# | Area | What’s Coming |
# |------|----------------|
# | **Foundation‑model scaling** | Models with >1 trillion parameters that can reason, plan, and self‑debug. |
# | **Neurosymbolic hybrids** | Combining neural generation with explicit symbolic reasoning for more reliable logic. |
# | **Real‑time multimodal generation** | Low‑latency video synthesis, interactive 3‑D scene creation. |
# | **Personalized agents** | Continual fine‑tuning on an individual’s data while preserving privacy (e.g., on‑device learning). |
# | **Energy‑efficient training** | Sparse models, reversible networks, and better hardware (e.g., AI‑optimized ASICs) to cut carbon footprints. |
# | **Regulatory frameworks** | Nations and industry groups are drafting standards for provenance, labeling, and liability of AI‑generated content. |
#
# ---
#
# ## TL;DR Summary
#
# - **Generative AI** = AI that **creates** new content (text, images, audio, video, code, etc.) rather than just classifying it.
# - It relies on massive datasets and neural architectures like **transformers**, **diffusion models**, and **GANs**.
# - Applications span **writing, design, software, education, healthcare, gaming**, and more.
# - Key challenges: **hallucinations, bias, misuse, resource cost**, all requiring robust safety and governance.
# - The field is rapidly converging on **multimodal, large‑scale, and increasingly controllable** models, with both commercial APIs and open‑source alternatives available today.
#
# If you have a specific use‑case or want to dive deeper into any of the model families, just let me know—I can walk you through code examples, evaluation metrics, or the latest research papers!
