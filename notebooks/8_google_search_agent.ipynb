# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langgraph.checkpoint.memory import MemorySaver

# %%
model =ChatGroq(model="openai/gpt-oss-120b")
search=GoogleSerperAPIWrapper()

# %%
search.run("Address of techno gamer")
# Out:
# "UJJWAL HOUSE ADDRESS REVEL | TECHNO GAMERZ HOME | UJJWAL ADDRESS IN DELHI. Visiting @TechnoGamerzOfficial House In Delhi !!! TECHNO GAMERZ HOUSE ADDRESS LEAKED. In this video, I am talking about- Tg Network is a YouTube Channel, where you will find gaming videos ( GTA ... Techno Gamer House in Duggal Housing,Delhi listed under Parks in Delhi. Rated 4.5 based on 40 Customer Reviews and Ratings with 1 Photos. Gamer, Streamer & Entertainer. Joining Good Game India as a Brand Ambassador and Judge. listed for in-person auditions in Mumbai or Delhi. We will give you Ujjwal Chaurasia-techno Gamerz's email address, phone number and address for their Agent and Publicist. Access contact ... TECHNO GAMERZ HOUSE ADDRESS LEAKED | TECHNO GAMERZ | UJJWAL GAMER. @UJJWALGAMERFANCLUB362 likes6.1K views1 year ago In this video PIRATES EAGLE talk about,Techno. Techno Gamerz gaming cafe address, Techno Gamerz address also techno Gamerz real life business, The registered address of TECHNO GAMERZ PRIVATE 
# ...

# %%
agent=create_agent(
    model=model,
    tools=[search.run],
    system_prompt="you are a agent and can search for any question on google.",
    checkpointer=MemorySaver()
)

# %%
question ="who won world cup 2025 cricket women"

# %%
question="Total Run ?"

# %%
response=agent.invoke(
    {"messages":[{"role":"user","content":question}]},
    {"configurable": {"thread_id": "asd123"}}
    )

# %%
print(response["messages"][-1].content)
# Out:
# **Total runs scored in the 2025 ICC Women’s Cricket World Cup:** **≈ 960 runs**
#
# - This figure comes from the official tournament statistics (Cricbuzz/ICC tracker) that list **“960 Total Runs”** for the entire competition (all group‑stage matches, semi‑finals and the final).
#
# So, across the whole 2025 Women’s World Cup, the teams combined to score roughly **nine hundred and sixty runs**.

# %%
response=agent.invoke(
    {"messages":[{"role":"user","content":question}]},
    {"configurable": {"thread_id": "asd"}}
    )

# %%
print(response["messages"][-1].content)
# Out:
# It looks like your question is a bit short, so I’m not sure exactly what you’re looking for. Could you please give me a little more detail? For example:
#
# - Are you asking about the **total run time** of a particular program, process, or event?
# - Do you want to know the **total distance run** (e.g., in a race, workout, or travel itinerary)?
# - Is “Total Run” the name of a product, service, or piece of software you’d like information about?
#
# Let me know what you have in mind, and I’ll be happy to help!
